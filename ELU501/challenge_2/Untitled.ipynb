# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Jul 26 16:09:11 2017

@author: cbothore
"""


import networkx as nx
import matplotlib.pyplot as plt
from matplotlib import pylab
import numpy as np
import pickle
from collections import Counter



def naive_method(graph, empty, attr):
    """   Predict the missing attribute with a simple but effective
    relational classifier. 
    
    The assumption is that two connected nodes are 
    likely to share the same attribute value. Here we chose the most frequently
    used attribute by the neighbors
    
    Parameters
    ----------
    graph : graph
       A networkx graph
    empty : list
       The nodes with empty attributes 
    attr : dict 
       A dict of attributes, either location, employer or college attributes. 
       key is a node, value is a list of attribute values.

    Returns
    -------
    predicted_values : dict 
       A dict of attributes, either location, employer or college attributes. 
       key is a node (from empty), value is a list of attribute values. Here 
       only 1 value in the list.
     """
    predicted_values={}
    for n in empty:
        nbrs_attr_values=[] ##coliect a set of empty nodes 
        for nbr in graph.neighbors(n):
            if nbr in attr:
                for val in attr[nbr]:
                    nbrs_attr_values.append(val)
        predicted_values[n]=[]
        if nbrs_attr_values: # non empty list
            # count the number of occurrence each value and returns a dict
            cpt=Counter(nbrs_attr_values)
            # take the most represented attribute value among neighbors
            a,nb_occurrence=max(cpt.items(), key=lambda t: t[1])
            predicted_values[n].append(a)
    return predicted_values
    
 
def evaluation_accuracy(groundtruth, pred):
    """    Compute the accuracy of your model.

     The accuracy is the proportion of true results.

    Parameters
    ----------
    groundtruth :  : dict 
       A dict of attributes, either location, employer or college attributes. 
       key is a node, value is a list of attribute values.
    pred : dict 
       A dict of attributes, either location, employer or college attributes. 
       key is a node, value is a list of attribute values. 

    Returns
    -------
    out : float
       Accuracy.
    """
    true_positive_prediction=0   
    for p_key, p_value in pred.items():
        if p_key in groundtruth:
            # if prediction is no attribute values, e.g. [] and so is the groundtruth
            # May happen
            if not p_value and not groundtruth[p_key]:
                true_positive_prediction+=1
            # counts the number of good prediction for node p_key
            # here len(p_value)=1 but we could have tried to predict more values
            true_positive_prediction += len([c for c in p_value if c in groundtruth[p_key]])          
        # no else, should not happen: train and test datasets are consistent
    return true_positive_prediction*100/sum(len(v) for v in pred.values())
   

# load the graph
G = nx.read_gexf("mediumLinkedin.gexf")
print("Nb of users in our graph: %d" % len(G))

# load the profiles. 3 files for each type of attribute
# Some nodes in G have no attributes
# Some nodes may have 1 attribute 'location'
# Some nodes may have 1 or more 'colleges' or 'employers', so we
# use dictionaries to store the attributes
college={}
location={}
employer={}
# The dictionaries are loaded as dictionaries from the disk (see pickle in Python doc)
with open('mediumCollege_60percent_of_empty_profile.pickle', 'rb') as handle:
    college = pickle.load(handle)
with open('mediumLocation_60percent_of_empty_profile.pickle', 'rb') as handle:
    location = pickle.load(handle)
with open('mediumEmployer_60percent_of_empty_profile.pickle', 'rb') as handle:
    employer = pickle.load(handle)

print("Nb of users with one or more attribute college: %d" % len(college))
print("Nb of users with one or more attribute location: %d" % len(location))
print("Nb of users with one or more attribute employer: %d" % len(employer))

# here are the empty nodes for whom your challenge is to find the profiles
empty_nodes=[]
with open('mediumRemovedNodes_60percent_of_empty_profile.pickle', 'rb') as handle:
    empty_nodes = pickle.load(handle)
print("Your mission, find attributes to %d users with empty profile" % len(empty_nodes))


# --------------------- Baseline method -------------------------------------#
# Try a naive method to predict attribute
# This will be a baseline method for you, i.e. you will compare your performance
# with this method
# Let's try with the attribute 'employer'
employer_predictions=naive_method(G, empty_nodes, employer)
groundtruth_employer={}
with open('mediumEmployer.pickle', 'rb') as handle:
    groundtruth_employer = pickle.load(handle)
result=evaluation_accuracy(groundtruth_employer,employer_predictions)
print("%f%% of the predictions are true" % result)
print("Very poor result!!! Try to do better!!!!")

# --------------------- Now your turn -------------------------------------#
# Explore, implement your strategy to fill empty profiles of empty_nodes


# and compare with the ground truth (what you should have predicted)
# user precision and recall measures
# Out:
# Nb of users in our graph: 811
# Nb of users with one or more attribute college: 230
# Nb of users with one or more attribute location: 336
# Nb of users with one or more attribute employer: 297
# Your mission, find attributes to 475 users with empty profile
# 19.696970% of the predictions are true
# Very poor result!!! Try to do better!!!!

# %%
employers={}
for (key,value) in employer.items():
    employers[key]=value
    print(key,value)
    print("********************************")
# Out:
# U1313 ['discovery education', 'ctb mcgraw-hill', 'university of charleston university of south carolina', 'south carolina department of education', 'chesapeake va and sumter sc', 'virgina state corrections']
# ********************************
# U8804 ['gruppo euris spa', 'iconsulting', 'econoetica', 'universit&#xe0; di bologna', 'university of illinois at urbana-champaign']
# ********************************
# U2649 ['bocom international', 'inventiv health', 'glaxosmithkline plc', 'zhongrong international trust co. ltd']
# ********************************
# U7310 ['microsoft', 'illinois computer technology', 'university of illinois at urbana-champaign', 'state farm insurance']
# ********************************
# U22859 ['amazon', 'ibm india research lab', 'coordinated science lab', 'toyota technical center']
# ********************************
# U1417 ['designing events']
# ********************************
# U25611 ['bluegranite', 'measured progress', 'sweetser']
# ********************************
# U3895 ['vertica systems an hp company', 'morgan stanley', 'microsoft', 'google']
# ********************************
# U13005 ['illinois state university', 'university of illinois at urbana-champaign']
# ********************************
# U9140 ['university of illinois at urbana-champaign', 'instituno nacional de estudos e pesquisas educacionais an&#xed;sio teixeira - inep', 'ipea']
# ********************************
# U16112 ['pwc']
# ********************************
# U7092 ['dropbox', 'orchestra inc.', 'hewlett-packard', 'state farm research and development center', 'university of illinois at urbana-champaign']
# ********************************
# U15272 ['uc berkeley', 'msr redmond', 'msr cambridge', 'university of waterloo', 'information engineers and consultants bangladesh ltd.']
# ********************************
# U3933 ['generalbiologic', 'hubs1', 'woyo.com', 'izenesoft (shanghai) co. ltd']
# ********************************
# U11562 ['university of illinois at urbana-champaign', 'microsoft', 'facebook']
# ********************************
# U22071 ['chicago public schools', 'illinois wesleyan development department', 'children&#x2019;s discovery museum', 'martin flory group']
# ********************************
# U15292 ['university of illinois at urbana-champaign', 'illinois state water survey prairie research institute', 'oklahoma state university', 'british american tobacco', 'bangladesh university of engineering &amp; technology', 'bangladesh insulation &amp; sanitary factory (bisf)']
# ********************************
# U14498 ['northern illinois university', 'university of wisconsin-madison', 'west virginia university']
# ********************************
# U21990 ['walmart', 'gilly hicks', 'campus recreation']
# ********************************
# U24252 ['viasat', 'george mason university']
# ********************************
# U12969 ['mckinley health center', 'university of illinois at urbana-champaign', 'all saints lutheran church', 'american cancer society', 'plush horse ice cream parlor']
# ********************************
# U27582 ['s&amp;p capital iq', 'university of illinois at urbana-champaign', 'kingtek corporation']
# ********************************
# U8029 ['presque isle county sheriff department']
# ********************************
# U27283 ['epic', 'bagtheweb inc.', 'university of illinois at urbana-champaign']
# ********************************
# U25619 ['humanex ventures', 'assessment learning and technology solutions (alts)', 'oasis institute of higher education', 'james madison university', 'gallup organization', 'presentation college san fernando', 'siparia senior comprehensive school']
# ********************************
# U2661 ['university of chicago', 'shanghai jiao tong university', 'microsoft research asia']
# ********************************
# U8000 ['aerofoams industries inc']
# ********************************
# U11591 ['office of community college research and leadership at university of illinois', 'family resiliency center uiuc', 'department of kinesiology and community health', 'department of educational psychology', 'chinese proficiency test center', 'beijing language and culture university']
# ********************************
# U27585 ['apple', 'university of pittsburgh school of information science', 'haoban digital co.']
# ********************************
# U1441 ['pacific metrics', 'pearson', 'james madison university', 'aicpa', 'guilford day school', 'guilford county schools']
# ********************************
# U2714 ['university of illinois at chicago', 'pohang university of science and technology']
# ********************************
# U18934 ['benjamin an and co. p.c.']
# ********************************
# U4638 ['broadcom', 'ucla', 'marvell']
# ********************************
# U7379 ['wood rodgers inc.', 'university of illinois at urbana-champaign', 'international water resources association', 'illini union board - mini courses', 'shell oil company']
# ********************************
# U15289 ['university of alabama at birmingham', 'bangladesh open source network', 'wikipedia', 'johns hopkins university', 'university of illinois at urbana-champaign', 'google', 'national center for supercomputing applications', 'bangladesh university of engineering and technology', 'dhaka international university']
# ********************************
# U14015 ['open systems laboratory university of illinois at urbana-champaign']
# ********************************
# U15329 ['bangladesh university of engineering and technology', 'odesk', 'freelancer.com', 'artcube media inc.', 'mazumder it limited']
# ********************************
# U24080 ['google', 'university of illinois at urbana-champaign', 'at&amp;t labs research', 'microsoft research asia']
# ********************************
# U18981 ['university of illinois at urbana-champaign']
# ********************************
# U3958 ['microsoft']
# ********************************
# U24046 ['whova', 'university of illinois at urbana-champaign', 'microsoft', 'google', 'chinese academy of sciences', 'fudan university']
# ********************************
# U11564 ['at&amp;t labs - research', 'university of michigan']
# ********************************
# U7213 ['deloitte', 'kpmg india', 'pepsico']
# ********************************
# U18954 ['illinois institute of technology', 'nec laboratories america', 'argonne national laboratory']
# ********************************
# U1045 ['measured progress', 'saint mary academy', 'psychometric society', 'act']
# ********************************
# U16132 ['argonne national laboratory']
# ********************************
# U7151 ['google', 'department of computer science | university of illinois', 'microsoft', 'bank of america merrill lynch', 'otcr consulting', 'black brothers co.']
# ********************************
# U15349 ['university of illinois at chicago', 'arris', 'qi analysis inc', 'ibais university', 'nazimcorp resource gateway']
# ********************************
# U27661 ['google', 'at&amp;t labs inc.', 'university of michigan']
# ********************************
# U22011 ['champaign unit 4 schools', 'danville community high school', 'project success vermillion county', 'geneva park district']
# ********************************
# U24154 ['google']
# ********************************
# U9130 ['illini art therapy association', 'university of illinois at urbana-champaign', 'southern illinois university', 'state university of new york at buffalo']
# ********************************
# U24254 ['new york university']
# ********************************
# U9660 ['kraft foods group', 'university of illinois at urbana-champaign', 'toyota']
# ********************************
# U2136 ['caterpillar']
# ********************************
# U1259 ['prometric', 'data recognition corporation', 'various public and private mental health centers clinics hospitals', 'institutional research analytical studies northern illinois university']
# ********************************
# U10051 ['krames staywell', 'cygnus business media', 'american academy of pediatrics']
# ********************************
# U19842 ['clorox company', 'department of chemical and biomolecular engineering at uiuc', 'unilever', 'flossmoor country club']
# ********************************
# U1220 ['excelsior college', 'university at albany', 'professional examination service']
# ********************************
# U1108 ['university of texas at austin']
# ********************************
# U1068 ['little brothers - friends of elderly', 'leaders in business development | marketing | united states', 'liaison international', 'pearson language tests', 'pearson knowledge technologies', 'ets']
# ********************************
# U24062 ['towers watson', 'pricewaterhousecoopers']
# ********************************
# U1252 ['stephanie gertz consulting']
# ********************************
# U27636 ['university of delaware', 'shanghai jiao tong university']
# ********************************
# U15168 ['ece department at uiuc', 'university of illinois at urbana-champaign']
# ********************************
# U13988 ['wolfram research']
# ********************************
# U14665 ['ara', 'iss inc.', 'eye center', 'university of illinois medical center', 'jingyi futures co. ltd', 'beihang university']
# ********************************
# U27614 ['yelp.com']
# ********************************
# U24117 ['blizzard entertainment', 'at&amp;t']
# ********************************
# U1136 ['educational testing service (ets)']
# ********************************
# U8699 ['university of illinois at urbana-champaign', 'google', 'cornell university', 'microsoft', 'ibm']
# ********************************
# U15321 ['weike gaming technology', 'itwin pte ltd.', 'tigerit bangladesh limited']
# ********************************
# U7117 ['intel corporation', 'paul kenis research group', 'john a. rogers research group']
# ********************************
# U4634 ['university of illinois at urbana-champaign', 'ge global research']
# ********************************
# U10631 ['ets']
# ********************************
# U18588 ['sheridan healthcorp']
# ********************************
# U27541 ['uc san diego', 'cisco systems', 'qad inc']
# ********************************
# U9655 ['arcelormittal', 'university of illinois kinesiology department', 'lincoln-way community high school', 'camp manitoqua and retreat center']
# ********************************
# U1196 ['center for educational testing and evaluation', 'national center for improvement of educational assessment inc', 'educational testing service', 'american institutes for research', 'pinkerton computer consultants inc', 'nyma inc', 'university of virginia', 'cornell university', 'reading is fundamental inc']
# ********************************
# U22019 ['north shore pediatric therapy', 'university of illinois at urbana-champaign', 'jewish child and family services', 'act one research services inc.']
# ********************************
# U9657 ['san diego gas &amp; electric', 'university of illinois at urbana-champaign', 'technische universit&#xe4;t darmstadt', 'kraft foods']
# ********************************
# U22828 ['bsb - bharti softbank']
# ********************************
# U6026 ['localytics']
# ********************************
# U13961 ['university of illinois at urbana-champaign', 'northern illinois university']
# ********************************
# U15932 ['brookhaven national laboratory', 'johns hopkins university']
# ********************************
# U14136 ['illinois state university', 'jcc of chicago', 'university of illinois at chicago-institute for juvenile research and hyperactivity attention and l', 'university of illinois at urbana-champaign', 'camp jrf', 'university of illinois at chicago &amp; jewish child and youth services']
# ********************************
# U27518 ['arizona state university']
# ********************************
# U27721 ['emsi']
# ********************************
# U24173 ['apostrophe solutions corp.', 'brock university', 'aramin information technology']
# ********************************
# U7283 ['ernst &amp; young', 'puma india', 'cmai', 'ample auto tech']
# ********************************
# U22072 ['wellness revolution', 'university of illinois at urbana-champaign', 'baby-speaking', 'round ground metals inc.', 'private']
# ********************************
# U7109 ['office of global and online education university of oregon', "women's resources center university of illinois at urbana-champaign", 'illinois leadership center university of illinois at urbana-champaign', 'alternative spring break at university of illinois', 'leadership conferences &amp; programs', 'southwestern company', 'office of business and financial services (obfs) university of illinois at urbana-champaign', 'm-i-c illinois']
# ********************************
# U5976 ['copper creek church', 'cv lloyde']
# ********************************
# U9689 ['general atomics', 'center for plasma and material interactions']
# ********************************
# U2209 ['esnet', 'buraglio consulting', 'university of illinois', 'national center for supercomputing applications', 'sol tec', 'country financial']
# ********************************
# U24084 ['apple', 'canesta', 'netease']
# ********************************
# U2761 ['google']
# ********************************
# U6021 ['sony biotechnology inc.']
# ********************************
# U13968 ['psycray corp', 'usa strategies inc.', 'affluence corporation', 'searchchannel llc']
# ********************************
# U1283 ['new jersey department of education']
# ********************************
# U7373 ['brookings institution', 'syrian emergency task force (setf)', 'muslim public affairs council', 'office of governor of illinois']
# ********************************
# U7272 ['tableau software', 'whitepages', 'yahoo! inc.']
# ********************************
# U1134 ['education analytics inc.', 'value-added research center at university of wisconsin', 'university of wisc. lafollette school of public affairs and wisconsin center for education research']
# ********************************
# U21998 ['illinois college advising corps', 'victoria amplifiers', 'university of illinois at chicago']
# ********************************
# U6000 ['merge llc', 'merge partners inc', 'vineyard church', 'state farm insurance', 'hearts at home']
# ********************************
# U1175 ['measured progress', 'questar assessment inc.', 'achievement data inc.']
# ********************************
# U13981 ['institute for transportation research and education (itre)', 'university of illinois at urbana-champaign']
# ********************************
# U15968 ['carl zeiss vision', 'booz &amp; company', 'freudenberg']
# ********************************
# U15299 ['jaxara', 'osource bangladesh']
# ********************************
# U9149 ['umass donahue institute']
# ********************************
# U6011 ['vizion interactive', 'search fanatics', 'click2rank consulting llc', 'seo by jt', 'innovadex', 'church of harvest', 't-mobile', 'mercy &amp; truth medical missions', 'security benefit']
# ********************************
# U25627 ['cardinal santos medical center', 'advanced orthopedics for joint replacement', 'manila doctors hospital']
# ********************************
# U18524 ['ultimate software', 'duque &amp; ruiz consulting s.l.', 'oracle', 'sun microsystems', 'seebeyond', 'newknow', 'meta4']
# ********************************
# U22017 ['comed', 'apple', 'olow charities', 'notes-n-quotes', 'praire ensemble', 't-initiative foundation', 'university of illinois']
# ********************************
# U1071 ['educational testing service (ets)']
# ********************************
# U18932 ['illinois state university']
# ********************************
# U15935 ['boston consulting group', 'itc limited']
# ********************************
# U25605 ['measured progress', "friendly's restaurant", 'iref iabs department']
# ********************************
# U27608 ['pine river capital management', 'microsoft bing search(bellevue u.s.a)', 'a.t.kearney', 'microsoft research redmond', 'idc', 'microsoft research asia', 'share', 'intel research']
# ********************************
# U8036 ['original profender', 'neshaminy school district']
# ********************************
# U7035 ['dunnhumby', 'nielsen company', 'state farm insurance', 'university of illinois-department of statistics', 'resident hall library', 'university of illinois at urbana-champaign - department of mathematics']
# ********************************
# U22771 ['apple inc.', 'university of texas at austin', 'infinera', 'texas instruments']
# ********************************
# U15994 ['brown and caldwell', 'tetra tech', 'american water works association']
# ********************************
# U15341 ['wichita state university', 'netapp', 'commlink info tech ltd.', 'atp solution']
# ********************************
# U3914 ['sjtu', 'taobao']
# ********************************
# U3919 ['mediav', 'yahoo! beijing r&amp;d', 'alibaba cloud computing company', 'microsoft global technology supporting center']
# ********************************
# U15917 ['cummins inc.', 'university of texas at austin', 'merl', 'zeus numerix', 'indian institute of science']
# ********************************
# U22843 ['tata consultancy services']
# ********************************
# U27507 ['goldman sachs', 'university of illinois at urbana-champaign']
# ********************************
# U4517 ['sanli pastore &amp; hill inc.', 'simpson &amp; simpson cpas', 'nepo inc.', 'china executive leadership program', 'kpmg', 'guangrui district financial department']
# ********************************
# U22785 ['pitney bowes']
# ********************************
# U22819 ['citi global markets']
# ********************************
# U1178 ['measured progress']
# ********************************
# U4676 ['nfls']
# ********************************
# U4489 ['university of illinois at urbana-champaign']
# ********************************
# U16089 ['quora', 'singapore-mit alliance for research &amp; technology', 'empiricus capital management group']
# ********************************
# U8076 ['us army']
# ********************************
# U22803 ['ca technologies']
# ********************************
# U27753 ['school of software shanghai jiao tong university']
# ********************************
# U15974 ['kisco global llc usa', 'kisco castings']
# ********************************
# U4647 ['pricewaterhousecoopers']
# ********************************
# U1104 ['universiti teknologi malaysia', 'national board of osteopathic medical examiner - clinical skills testing', 'center for educational testing and evaluation', 'center for research on learning', 'university of kansas']
# ********************************
# U16137 ['cummins inc.']
# ********************************
# U2631 ['university of texas at austin', 'google', 'microsoft research asia', 'msra-ucla research in industrial projects for students']
# ********************************
# U24218 ['lucena research', 'georgia institute of technology']
# ********************************
# U9709 ['lyondellbasell', 'university of alabama', 'subway', 'girl scouts of western ohio']
# ********************************
# U2622 ['yahoo! labs', 'idiap research institute', 'eth z&#xfc;rich', 'mit', 'computer vision &amp; active perception lab (cvap) kth']
# ********************************
# U14532 ['legacy investment advisors llc']
# ********************************
# U27691 ['north carolina state university', 'national chiao tung university']
# ********************************
# U1282 ['michigan state university', 'educational testing service', 'act inc', 'can tho university vietnam', 'ghent university belgium']
# ********************************
# U8909 ['john birch society', "perkins county sheriff's department"]
# ********************************
# U3909 ['microsoft', 'alibaba.com']
# ********************************
# U16101 ['idg ventures', 'axdia international gmbh', 'fraunhofer iais', 'idg media fundation']
# ********************************
# U21443 ['university of illinois at urbana-champaign']
# ********************************
# U8088 ['hanwha l&c alabama']
# ********************************
# U7270 ['goldman sachs', 'illinois business consulting', 'university of illinois at urbana-champaign']
# ********************************
# U22799 ['amazon']
# ********************************
# U15307 ['kona software lab ltd. (r&amp;d center of konai s. korea))', 'bangladesh bureau of statistics', 'progmaatic developer network', 'dhaka - gtug', 'technology solutions limited']
# ********************************
# U9665 ['argonne national laboratory']
# ********************************
# U5981 ['elemental imaging', 'command performance research', 'killer works', 'undisclosed', 'actency', 'abner guzman phd', 'uiknow inc.', 'electronic arts', 'department of computer science university of illinois at urbana-champaign', 'motorola', 'mimosa accoustics', 'gas technology institute', 'baxter healthcare']
# ********************************
# U1199 ['data recognition corporation', 'ctb mcgraw-hill', 'georgia center for assessment at uga', 'ets', 'ctb mcgraw hill']
# ********************************
# U22747 ['university of illinois at urbana-champaign', 'intel', 'oracle india pvt ltd', 'microsoft research india labs', 'bhabha atomic research center']
# ********************************
# U1089 ['university of iowa']
# ********************************
# U18916 ['university of illinois at urbana-champaign']
# ********************************
# U14500 ['empowered u coaching', 'mahomet-seymour pto', 'simplified computers', 'vineyard bible institute', 'vineyard church', 'franklin magnet middle school']
# ********************************
# U7349 ['glenbard township high school district 87', 'grainger engineering library', 'alternative spring break', 'university of illinois at urbana-champaign', 'university ymca', 'university of ymca student board', 'resolutions employment assistant program']
# ********************************
# U3894 ['trivest', 'shanghai prosperity fund', 'cid group']
# ********************************
# U27642 ['quantcast']
# ********************************
# U9122 ['university of illinois at urbana-champaign']
# ********************************
# U16204 ['harvard school of public health', 'university of michigan', 'hkust']
# ********************************
# U27772 ['university of south florida']
# ********************************
# U24064 ['twitter']
# ********************************
# U21995 ['university of illinois at urbana-champaign']
# ********************************
# U9128 ['hughes development corp', 'albrecht imaging', 'confidential', 'university of illinois at urbana-champaign', 'my place bar and grill', 'dupont']
# ********************************
# U25641 ['hopewell consulting llc', 'educational testing service']
# ********************************
# U15334 ['admetrics communications', 'university of british columbia', 'dohatec new media']
# ********************************
# U9667 ['john deere', 'chillers inc', 'panera bread']
# ********************************
# U11597 ['baidu inc.']
# ********************************
# U27742 ['university of southern california', 'university of delaware']
# ********************************
# U8113 ['delaware diamond knives']
# ********************************
# U7317 ['aerofs', 'bazaarvoice', 'university of illinois at urbana-champaign', 'cisco systems', 'readjournal']
# ********************************
# U1238 ['international center for leadership in education', 'smarter balanced assessment consortium', 'council of chief state school officers (ccsso)', 'maine department of education']
# ********************************
# U7909 ['reasoning mind', 'houston isd', 'university of illinois at urbana-champaign', 'inc research']
# ********************************
# U14125 ['software competitiveness international', 'wexgroup', 'intered']
# ********************************
# U19831 ['young business professionals of coastal bend', 'celanese', 'university of illinois at urbana-champaign', 'american institute of chemical engineers', 'dow corning', 'exelon nuclear']
# ********************************
# U22030 ['university of illinois at urbana-champaign crop sciences', 'krannert center for performing arts', 'alternative spring break at university of illinois', 'cognitive neuroimaging laboratory', 'american medical student association at university of illinois', 'prospect heights park district', 'provena covenant medical center']
# ********************************
# U27618 ['university of illinois at urbana-champaign']
# ********************************
# U13959 ['microsoft', 'university of illinois at urbana-champaign', 'morgan stanley', 'alcatel-lucent - bell labs']
# ********************************
# U24550 ['university of illinois at urbana-champaign', "st. jude's recovery center", 'girl scouts of greater atlanta inc.']
# ********************************
# U9141 ['i-stem education initiative', 'university of illinois at urbana-champaign', 'university of chicago', 'pilsen wellness center inc.']
# ********************************
# U7096 ['cosmopolitan magazine india', 'mega modelz magazine', 'impulse films - filmmaking workshops']
# ********************************
# U8049 ['cold hand arms llc']
# ********************************
# U7315 ['university of illinois at urbana-champaign', 'walsh construction', 'city of champaign public works', 'deloitte consulting', 'university of illinois mathematics department', 'building research council']
# ********************************
# U16141 ['oracle', 'dartmouth college', 'digital finance software development company ltd', 'frontfree technology network']
# ********************************
# U27763 ['microsoft', 'morgan stanley']
# ********************************
# U15311 ['university of waterloo', 'runner cyberlink ltd. (bd)', 'buet', 'bangladesh university of engineering &amp; technology']
# ********************************
# U1147 ['ets', 'educational testing service']
# ********************************
# U15944 ['brown and caldwell', 'university of illinois at urbana-champaign']
# ********************************
# U7347 ['university housing', 'hydrosystems laboratory', 'ch2m hill']
# ********************************
# U14068 ['university of illinois at urbana-champaign']
# ********************************
# U16127 ['robert bosch gmbh', 'schlumberger', 'mathematical biosciences institute ohio state univeristy', 'institute for mathematics and its application university of minnesota', 'stanford university']
# ********************************
# U18562 ['ultimate software', 'motorola inc. plantation fl', 'motorola inc. boynton beach fl', 'hcs lab university of florida', 'fiu university computer services']
# ********************************
# U4457 ['university of illinois at urbana-champaign', 'aia', 'beijing municipal bureau of statistics']
# ********************************
# U7294 ['goldman sachs']
# ********************************
# U7295 ['galt &amp; company', 'abbott laboratories', 'zs associates', 'abbott diabetes care']
# ********************************
# U7338 ['hitachi consulting', 'procter &amp; gamble', 'university of illinois foundation', 'tepper mann &amp; cottrell p.c', 'self', 'round lake area park district']
# ********************************
# U5980 ['shapemaster inc.']
# ********************************
# U27617 ['university of illinois at urbana-champaign']
# ********************************
# U19874 ['university of illinois at urbana-champaign', 'oak ridge national laboratory', 'sauk valley community college', 'us army']
# ********************************
# U22088 ['university of illinois at springfield', 'family video']
# ********************************
# U9630 ['state farm', 'illinois business consulting']
# ********************************
# U18983 ['greenpeace', 'big appetite network', 'global campaign for climate action (gcca)', 'undp', 'carnegie endowment for international peace', 'global social venture competition']
# ********************************
# U8900 ['northgate church']
# ********************************
# U2746 ['linkedin', 'university of massachusetts amherst', 'beijing institute of technology']
# ********************************
# U13032 ['roosevelt university: counseling center', 'roosevelt university: melissa sisco ph.d', 'university of illinois at urbana-champaign', "women's resource center", 'american eagle outfitters', 'roland realty']
# ********************************
# U27648 ['rutgers university', 'shanghai jiao tong university', 'intel']
# ********************************
# U2140 ['semprius', 'university of illinois at urbana-champaign']
# ********************************
# U9680 ['champaign-urbana community fabrication laboratory', 'manplan inc']
# ********************************
# U21838 ['lacunavinea inc. nfp', 'vibes media']
# ********************************
# U24113 ['stanford university']
# ********************************
# U25618 ['sophos']
# ********************************
# U8090 ['arch crown inc', 'raider performance', 'lda technical consulting llc']
# ********************************
# U7983 ['keller williams-inskip realtyteam', 'keller williams realty', 'rector property management']
# ********************************
# U24177 ['gfk', 'celonis gmbh', 'apa-iutcert', 'farabord']
# ********************************
# U15919 ['avanti fellows', 'cognizant technology solutions']
# ********************************
# U2680 ['university of illinois at chicago']
# ********************************
# U15333 ['university of illinois at urbana-champaign', 'ebay inc', 'groupon', 'state farm insurance', 'engineering it shared services', 'prof. lawrence angrave research group', 'shahjalal university of science and technology']
# ********************************
# U24247 ['university of illinois at urbana-champaign', 'i coppi', 'ingaldsby farm']
# ********************************
# U1303 ['graduate school city university of new york', 'center for advanced study in education']
# ********************************
# U7253 ['university of illinois at urbana-champaign', 'boeing', 'harper community college']
# ********************************
# U24158 ['shega', 'ific']
# ********************************
# U8721 ['google', 'university of illinois at urbana-champaign', 'hewlett-packard laboratories', 'yahoo!']
# ********************************
# U27707 ['university of illinois at urbana-champaign', 'microsoft', 'intel china research center']
# ********************************
# U2663 ['zhejiang university', 'ucla', 'microsoft research china']
# ********************************
# U27542 ['commerzbank ag', 'capstone investment advisors']
# ********************************
# U7370 ['siemens healthcare']
# ********************************
# U27332 ['amazon', 'standard chartered bank', 'no.1 puppy']
# ********************************
# U24184 ['spot trading llc', 'intelligent medical objects', 'dr. h.r thompson md', 'china automotive industry engineering corp.']
# ********************************
# U14131 ['facebook', 'microsoft', 'google', 'telco in a box', 'university of new south wales']
# ********************************
# U8050 ['self-employed']
# ********************************
# U22753 ['amazon.com', 'oracle', 'intel corporation', 'yahoo!', 'bhabha atomic research center']
# ********************************
# U3989 ["noah's ark lab huawei technologies co. ltd.", 'baidu inc.']
# ********************************
# U18928 ['daimler trucks north america', 'ace properties and management llc', 'caterpillar inc.', 'caterpillar champaign simulation center', 'university of illinois at urbana-champaign', 'science technology and information center national science council', 'corporate synergy development center']
# ********************************
# U14566 ['faa']
# ********************************
# U8100 ['boda corporation', 'black squirrel bed &amp; breakfast', 'harra decal', 'murfin division menasha corporation']
# ********************************
# U1055 ['graduate management admission council&#xae; (gmac&#xae;)', 'university of massachusetts amherst', 'republic of korea army']
# ********************************
# U4542 ['caterpillar inc.', 'university of illinois at urbana-champaign', 'nondestructive tesing center tsinghua univ.']
# ********************************
# U4568 ['google', 'university of illinois at urbana-champaign', 'samsung', 'bell laboratories']
# ********************************
# U22074 ['university of illinois at chicago', 'university of illinois springfield']
# ********************************
# U22045 ['chicago public schools']
# ********************************
# U18555 ['mindtree ltd.', 'university of florida', 'niche mobile', 'programming team', 'samuel p. harn museum of art', 'morikami museum and japanese gardens']
# ********************************
# U8741 ['systems research group university of illinois at urbana-champaign', 'fujitsu laboratories of america', 'nasa goddard space flight center', 'california institute for telecommunications and information technology', 'uci computer graphics group', 'smsold']
# ********************************
# U24238 ['university of alberta']
# ********************************
# U8768 ['microsoft research', 'university of illinois at urbana-champaign', 'hewlett-packard laboratories', 'xerox innovation group xerox research center webster', 'university of waterloo', 'bangladesh university of engineering &amp; technology']
# ********************************
# U14531 ['vineyard church of paxton illinois', 'vineyard bible institute', 'abbott power plant university of illinois']
# ********************************
# U8098 ['federal law enforcement training center', 'west park digital media', 'illinois state police investigations', 'natia']
# ********************************
# U9126 ['office of community college research and leadership', 'higher learning commission', 'chaparral college']
# ********************************
# U15949 ['deutsche bank']
# ********************************
# U15294 ['texas tech university']
# ********************************
# U14547 ['express employment professionals', 'chitralada palace school', 'hyatt regency hill country resort and spa']
# ********************************
# U25610 ['abacus automation', 'donald j. allen']
# ********************************
# U15482 ['keller williams realty trec llc']
# ********************************
# U27475 ['university of texas at austin', 'paypal', 'yelp.com', 'samsung engineering &amp; construction', 'protect america inc.', 'ellusionist inc.', 'adaptive home inc', 'tokyo steakhouse', 'modern japan development llp']
# ********************************
# U27704 ['university of illinois at urbana-champaign']
# ********************************
# U16153 ['university of michigan health system', 'boston consulting group', 'center for entrepreneurship university of michigan', 'mckinsey &amp; company', 'daolan group', 'peking university']
# ********************************
# U27494 ['google', 'alibaba cloud computing', 'eleme inc.', 'microsoft']
# ********************************
# U11563 ['university of illinois at urbana-champaign', 'ebay']
# ********************************
# U7281 ['idubba.com', 'mozilla corporation', 'x.org']
# ********************************
# U4485 ['university of illinois at urbana-champaign', 'center for study of reading']
# ********************************
# U14080 ['university of illinois at urbana-champaign', 'hewlett-packard laboratories', 'independent contractor', 'microsoft', 'oracle']
# ********************************
# U16091 ['wichita state university', 'state farm', 'university of illinois at urbana-champaign', 'sr research inc', 'eptco group', 'peking university', 'microsoft']
# ********************************
# U18964 ['naturelaw international consulting company']
# ********************************
# U18570 ['ultimate software', 'amazon', 'orlando utilities commission']
# ********************************
# U22861 ['reliance', 'bharti airtel limited']
# ********************************
# U27758 ['google']
# ********************************
# U14150 ['transpac aviation academy', 'university of illinois at urbana-champaign', 'ja air center']
# ********************************
# U15342 ['university of illinois at urbana-champaign']
# ********************************
# U24183 ['consolsys sdn bhd', 'mabna card aria', 'persian easy payment', 'gaj (jokaar educational group)', 'idea negar energy sabz', 'tsp - keymile', 'javaneh software co.']
# ********************************
# U7141 ['amazon', 'university of illinois at urbana-champaign', 'qualcomm', 'research in motion']
# ********************************
# U16085 ['globalfoundries']
# ********************************
# U15286 ['dhi']
# ********************************
# U4606 ['3m', 'university of illinois at urbana-champaign']
# ********************************
# U21969 ['university of illinois at urbana-champaign', 'universty of illinois residence halls', "hillery's bar-b-que"]
# ********************************
# U4005 ['wayfair', 'bloomberg']
# ********************************
# U14123 ['niksun', 'university of illinois at urbana-champaign', 'ieee']
# ********************************
# U7377 ['cancer prevention and research institute of texas', 'hostgator.com', 'threads of time', 'university of illinois at urbana-champaign']
# ********************************
# U9711 ['qualcomm', 'ibm', 'fermilab', 'wolfram research']
# ********************************
# U2180 ['riverbed technology', 'luster software', 'health alliance medical plans', 'ral recoveries', 'personalcare']
# ********************************
# U24224 ['neustar inc.']
# ********************************
# U7402 ['huntington learning center', 'uiuc communications library', 'students for life of illinois', 'university of illinois at urbana-champaign', 'missionyouth pastoral support services']
# ********************************
# U28772 ['honda research institute usa inc.', 'ibm', 'cycorp']
# ********************************
# U27761 ['3m', 'general electric']
# ********************************
# U14007 ['university of illinois at urbana-champaign', 'par works inc. (an allied minds company)']
# ********************************
# U8795 ['university of illinois at urbana-champaign', 'nec laboratories america', 'pinpoint!me', 'nvidia']
# ********************************
# U15197 ['qualcomm innovation center inc', 'campus information technologies and educational services', 'smartplay technologies']
# ********************************
# U27777 ['yuhuan taijie hardware co. ltd.']
# ********************************
# U8828 ['university of illinois at urbana-champaign']
# ********************************

# %%
college_complete={}
location_complete={}
employer_complete={}
# The dictionaries are loaded as dictionaries from the disk (see pickle in Python doc)
with open('mediumCollege.pickle', 'rb') as handle:
    college_complete = pickle.load(handle)
with open('mediumLocation.pickle', 'rb') as handle:
    location_complete = pickle.load(handle)
with open('mediumEmployer.pickle', 'rb') as handle:
    employer_complete = pickle.load(handle)

print("Nb of users with one or more attribute employer_complete: %d" % len(college_complete))
print("Nb of users with one or more attribute location_complete: %d" % len(location_complete))
print("Nb of users with one or more attribute employer_complete: %d" % len(employer_complete))
# Out:
# Nb of users with one or more attribute employer_complete: 540
# Nb of users with one or more attribute location_complete: 811
# Nb of users with one or more attribute employer_complete: 730
